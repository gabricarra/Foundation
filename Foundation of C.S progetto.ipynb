# %% [markdown]
# # Foundation of Computer Science

# %% [markdown]
# Richiesta:
#
# 1.Normalize the loan_lenders table. In the normalized table, each row must have one loan_id and one lender.
#
# 2.For each loan, add a column duration corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.
#
# 3.Find the lenders that have funded at least twice.
#
# 4.For each country, compute how many loans have involved that country as borrowers.
#
# 5.For each country, compute the overall amount of money borrowed.
#
# 6.Like the previous point, but expressed as a percentage of the overall amount lent.
#
# 7.Like the three previous points, but split for each year (with respect to disburse time).
#
# 8.For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.
#
# 9.For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.
#
# 10.Which country has the highest ratio between the difference computed at the previous point and the population?
#
# 11.Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?
#
# 12.For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD 31 / (31+365+30) = 363.85 for 2016, 5000USD 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# #### 1.Normalize the loan_lenders table. In the normalized table, each row must have one loan_id and one lender.

# %%
loans_lenders=pd.read_csv('loans_lenders.csv')
loans_lenders.head()
# Out:
#    loan_id                                            lenders
# 0   483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1   483738  muc888, nora3555, williammanashi, barbara5610,...
# 2   485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3   486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4   534428  muc888, niki3008, teresa9174, mike4896, david7...

# %%
norm=loans_lenders.assign(lenders=loans_lenders['lenders'].str.split(',')).explode('lenders')

# %%
norm.reset_index(drop= True)
# Out:
#           loan_id             lenders
# 0          483693              muc888
# 1          483693             sam4326
# 2          483693         camaran3922
# 3          483693         lachheb1865
# 4          483693         rebecca3499
# ...           ...                 ...
# 28293926  1206425   trogdorfamily7622
# 28293927  1206425           danny6470
# 28293928  1206425             don6118
# 28293929  1206486            alan5175
# 28293930  1206486         amy38101311
#
# [28293931 rows x 2 columns]

# %% [markdown]
# #### 2.For each loan, add a column duration corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.

# %%
loans= pd.read_csv('loans.csv')

# %%
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ...  \
# 0        125.0  funded  General Store       Retail  ...
# 1        400.0  funded  Used Clothing     Clothing  ...
# 2        400.0  funded  General Store       Retail  ...
# 3        625.0  funded        Farming  Agriculture  ...
# 4        425.0  funded        Farming  Agriculture  ...
#
#                      raised_time lender_term num_lenders_total  \
# 0  2014-01-15 04:48:22.000 +0000         7.0                 3
# 1  2014-02-25 06:42:06.000 +0000         8.0                11
# 2  2014-01-24 23:06:18.000 +0000        14.0                16
# 3  2014-01-22 05:29:28.000 +0000        14.0                21
# 4  2014-01-14 17:29:27.000 +0000         7.0                15
#
#   num_journal_entries num_bulk_entries  \
# 0                   2                1
# 1                   2                1
# 2                   2                1
# 3                   2                1
# 4                   2                1
#
#                                                 tags borrower_genders  \
# 0                                                NaN           female
# 1                                                NaN           female
# 2  #Woman Owned Biz, #Supporting Family, user_fav...           female
# 3                                      user_favorite           female
# 4           #Animals, #Eco-friendly, #Sustainable Ag             male
#
#    borrower_pictured repayment_interval distribution_model
# 0               true          irregular      field_partner
# 1               true            monthly      field_partner
# 2               true            monthly      field_partner
# 3               true            monthly      field_partner
# 4               true             bullet      field_partner
#
# [5 rows x 31 columns]

# %%
loans['disburse_time']=pd.to_datetime(loans['disburse_time'])
loans['planned_expiration_time']=pd.to_datetime(loans['planned_expiration_time'])
loans['duration']= loans['planned_expiration_time']-loans['disburse_time']
#eventuali na generano risultati na in automatico

# %%
loans[['loan_id', 'planned_expiration_time', 'disburse_time', 'duration']]
# Out:
#          loan_id   planned_expiration_time             disburse_time  \
# 0         657307 2014-02-14 03:30:06+00:00 2013-12-22 08:00:00+00:00
# 1         657259 2014-03-26 22:25:07+00:00 2013-12-20 08:00:00+00:00
# 2         658010 2014-02-15 21:10:05+00:00 2014-01-09 08:00:00+00:00
# 3         659347 2014-02-21 03:10:02+00:00 2014-01-17 08:00:00+00:00
# 4         656933 2014-02-13 06:10:02+00:00 2013-12-17 08:00:00+00:00
# ...          ...                       ...                       ...
# 1419602   988180 2016-01-02 01:00:03+00:00 2015-11-23 08:00:00+00:00
# 1419603   988213 2016-01-02 16:40:07+00:00 2015-11-24 08:00:00+00:00
# 1419604   989109 2016-01-03 22:20:04+00:00 2015-11-13 08:00:00+00:00
# 1419605   989143 2016-01-05 08:50:02+00:00 2015-11-03 08:00:00+00:00
# 1419606   989240 2016-01-03 20:50:06+00:00 2015-11-03 08:00:00+00:00
#
#                 duration
# 0       53 days 19:30:06
# 1       96 days 14:25:07
# 2       37 days 13:10:05
# 3       34 days 19:10:02
# 4       57 days 22:10:02
# ...                  ...
# 1419602 39 days 17:00:03
# 1419603 39 days 08:40:07
# 1419604 51 days 14:20:04
# 1419605 63 days 00:50:02
# 1419606 61 days 12:50:06
#
# [1419607 rows x 4 columns]

# %% [markdown]
# #### 3.Find the lenders that have funded at least twice.

# %%
lenders_times = norm.groupby('lenders').count()
lenders_times.head()
# Out:
#                  loan_id
# lenders
#  000                  39
#  00000                39
#  0002                 70
#  00mike00              1
#  0101craign0101       71

# %%
lenders_times.columns=['count']

# %%
lenders_two_times= lenders_times[lenders_times['count']>1]
lenders_two_times
# Out:
#                  count
# lenders
#  000                39
#  00000              39
#  0002               70
#  0101craign0101     71
#  0132575             4
# ...                ...
# zyrorl               3
# zzaman              11
# zzanita              2
# zzmcfate            56
# zzrvmf8538           2
#
# [1005111 rows x 1 columns]

# %% [markdown]
# #### 4.For each country, compute how many loans have involved that country as borrowers

# %%
loans_country = loans.groupby('country_name').count()
loans_country
# Out:
#                 loan_id  loan_name  original_language  description  \
# country_name
# Afghanistan        2337       1684               1684         1684
# Albania            3075       2998               2998         2998
# Armenia           13952      13926              13926        13926
# Azerbaijan        10172       9890               9890         9890
# Belize              218        171                171          171
# ...                 ...        ...                ...          ...
# Vietnam           21839      21788              21788        21767
# Virgin Islands        2          2                  2            2
# Yemen              4206       3436               3436         3436
# Zambia             1277       1158               1159         1159
# Zimbabwe           5513       5290               5290         5290
#
#                 description_translated  funded_amount  loan_amount  status  \
# country_name
# Afghanistan                          2           2337         2337    2337
# Albania                           2162           3075         3075    3075
# Armenia                           9568          13952        13952   13952
# Azerbaijan                        2320          10172        10172   10172
# Belize                              92            218          218     218
# ...                                ...            ...          ...     ...
# Vietnam                          13715          21839        21839   21839
# Virgin Islands                       2              2            2       2
# Yemen                             1508           4206         4206    4206
# Zambia                             971           1277         1277    1277
# Zimbabwe                          4479           5513         5513    5513
#
#                 activity_name  sector_name  ...  lender_term  \
# country_name                                ...
# Afghanistan              2337         2337  ...         2337
# Albania                  3075         3075  ...         3075
# Armenia                 13952        13952  ...        13952
# Azerbaijan              10172        10172  ...        10172
# Belize                    218          218  ...          218
# ...                       ...          ...  ...          ...
# Vietnam                 21839        21839  ...        21839
# Virgin Islands              2            2  ...            2
# Yemen                    4206         4206  ...         4206
# Zambia                   1277         1277  ...         1277
# Zimbabwe                 5513         5513  ...         5513
#
#                 num_lenders_total  num_journal_entries  num_bulk_entries  \
# country_name
# Afghanistan                  2337                 2337              2337
# Albania                      3075                 3075              3075
# Armenia                     13952                13952             13952
# Azerbaijan                  10172                10172             10172
# Belize                        218                  218               218
# ...                           ...                  ...               ...
# Vietnam                     21839                21839             21839
# Virgin Islands                  2                    2                 2
# Yemen                        4206                 4206              4206
# Zambia                       1277                 1277              1277
# Zimbabwe                     5513                 5513              5513
#
#                  tags  borrower_genders  borrower_pictured  \
# country_name
# Afghanistan        12              1684               1684
# Albania          2379              2998               2998
# Armenia         10622             13926              13926
# Azerbaijan       2576              9890               9890
# Belize             83               171                171
# ...               ...               ...                ...
# Vietnam         12417             21788              21788
# Virgin Islands      0                 2                  2
# Yemen            2224              3436               3436
# Zambia           1069              1159               1159
# Zimbabwe         4067              5290               5290
#
#                 repayment_interval  distribution_model  duration
# country_name
# Afghanistan                   2337                2337         2
# Albania                       3075                3075      3075
# Armenia                      13952               13952     12809
# Azerbaijan                   10172               10172      4026
# Belize                         218                 218       218
# ...                            ...                 ...       ...
# Vietnam                      21839               21839     16371
# Virgin Islands                   2                   2         0
# Yemen                         4206                4206      4184
# Zambia                        1277                1277      1277
# Zimbabwe                      5513                5513      5075
#
# [96 rows x 31 columns]

# %%
loans_country = loans_country[['loan_id']]
loans_country.columns=['times']
loans_country
# Out:
#                 times
# country_name
# Afghanistan      2337
# Albania          3075
# Armenia         13952
# Azerbaijan      10172
# Belize            218
# ...               ...
# Vietnam         21839
# Virgin Islands      2
# Yemen            4206
# Zambia           1277
# Zimbabwe         5513
#
# [96 rows x 1 columns]

# %% [markdown]
# #### 5.For each country, compute the overall amount of money borrowed

# %%
money_country = loans.groupby('country_name')['loan_amount'].sum()

# %%
money_country=money_country.to_frame()
money_country
# Out:
#                 loan_amount
# country_name
# Afghanistan       1967950.0
# Albania           4307350.0
# Armenia          22950475.0
# Azerbaijan       14784625.0
# Belize             150175.0
# ...                     ...
# Vietnam          24681100.0
# Virgin Islands      10000.0
# Yemen             3444000.0
# Zambia            1978975.0
# Zimbabwe          5851875.0
#
# [96 rows x 1 columns]

# %% [markdown]
# #### 6.Like the previous point, but expressed as a percentage of the overall amount lent.

# %%
money_country['percentage']= money_country['loan_amount']/sum(money_country['loan_amount'])*100

# %%
money_country
# Out:
#                 loan_amount  percentage
# country_name
# Afghanistan       1967950.0    0.166573
# Albania           4307350.0    0.364586
# Armenia          22950475.0    1.942589
# Azerbaijan       14784625.0    1.251410
# Belize             150175.0    0.012711
# ...                     ...         ...
# Vietnam          24681100.0    2.089074
# Virgin Islands      10000.0    0.000846
# Yemen             3444000.0    0.291509
# Zambia            1978975.0    0.167506
# Zimbabwe          5851875.0    0.495318
#
# [96 rows x 2 columns]

# %% [markdown]
# #### 7.Like the three previous points, but split for each year (with respect to disburse time).

# %%
loans['disburse_year']= loans['disburse_time'].dt.year
loans[['disburse_year', 'disburse_time']]
# Out:
#          disburse_year             disburse_time
# 0               2013.0 2013-12-22 08:00:00+00:00
# 1               2013.0 2013-12-20 08:00:00+00:00
# 2               2014.0 2014-01-09 08:00:00+00:00
# 3               2014.0 2014-01-17 08:00:00+00:00
# 4               2013.0 2013-12-17 08:00:00+00:00
# ...                ...                       ...
# 1419602         2015.0 2015-11-23 08:00:00+00:00
# 1419603         2015.0 2015-11-24 08:00:00+00:00
# 1419604         2015.0 2015-11-13 08:00:00+00:00
# 1419605         2015.0 2015-11-03 08:00:00+00:00
# 1419606         2015.0 2015-11-03 08:00:00+00:00
#
# [1419607 rows x 2 columns]

# %% [markdown]
# like point 4

# %%
loans_country_year = loans.groupby(['country_name', 'disburse_year'] ).count()['loan_id']
loans_country_year= loans_country_year.to_frame()
loans_country_year
# Out:
#                             loan_id
# country_name disburse_year
# Afghanistan  2007.0             408
#              2008.0             370
#              2009.0             678
#              2010.0             632
#              2011.0             247
# ...                             ...
# Zimbabwe     2013.0             426
#              2014.0            2078
#              2015.0             600
#              2016.0             808
#              2017.0            1079
#
# [748 rows x 1 columns]

# %%
loans_country_year.columns=['times']
loans_country_year
# Out:
#                             times
# country_name disburse_year
# Afghanistan  2007.0           408
#              2008.0           370
#              2009.0           678
#              2010.0           632
#              2011.0           247
# ...                           ...
# Zimbabwe     2013.0           426
#              2014.0          2078
#              2015.0           600
#              2016.0           808
#              2017.0          1079
#
# [748 rows x 1 columns]

# %% [markdown]
# like point 5

# %%
money_country_year = loans.groupby(['country_name', 'disburse_year']).sum()['loan_amount']
money_country_year=money_country_year.to_frame()
money_country_year
# Out:
#                             loan_amount
# country_name disburse_year
# Afghanistan  2007.0            194975.0
#              2008.0            365375.0
#              2009.0            585125.0
#              2010.0            563350.0
#              2011.0            245125.0
# ...                                 ...
# Zimbabwe     2013.0            678525.0
#              2014.0           1311575.0
#              2015.0            723625.0
#              2016.0            788600.0
#              2017.0           1237600.0
#
# [748 rows x 1 columns]

# %% [markdown]
# like point 6

# %%
money_country_year['percentage']= money_country_year['loan_amount']/sum(money_country_year['loan_amount'])*100
money_country_year
# Out:
#                             loan_amount  percentage
# country_name disburse_year
# Afghanistan  2007.0            194975.0    0.016657
#              2008.0            365375.0    0.031215
#              2009.0            585125.0    0.049989
#              2010.0            563350.0    0.048129
#              2011.0            245125.0    0.020942
# ...                                 ...         ...
# Zimbabwe     2013.0            678525.0    0.057969
#              2014.0           1311575.0    0.112053
#              2015.0            723625.0    0.061822
#              2016.0            788600.0    0.067373
#              2017.0           1237600.0    0.105733
#
# [748 rows x 2 columns]

# %% [markdown]
# #### 8.For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.

# %%
lenders_per_loan = norm.groupby('loan_id').count()
lenders_per_loan
# Out:
#          lenders
# loan_id
# 84             3
# 85             2
# 86             3
# 88             3
# 89             4
# ...          ...
# 1444051        1
# 1444053        1
# 1444058        1
# 1444063        1
# 1444065        1
#
# [1387432 rows x 1 columns]

# %%
lenders_per_loan.columns=['num_lenders']
lenders_per_loan
# Out:
#          num_lenders
# loan_id
# 84                 3
# 85                 2
# 86                 3
# 88                 3
# 89                 4
# ...              ...
# 1444051            1
# 1444053            1
# 1444058            1
# 1444063            1
# 1444065            1
#
# [1387432 rows x 1 columns]

# %%
money_lent = lenders_per_loan.merge(loans[['loan_id', 'loan_amount']], on='loan_id')
money_lent
# Out:
#          loan_id  num_lenders  loan_amount
# 0             84            3        500.0
# 1             85            2        500.0
# 2             86            3        500.0
# 3             88            3        300.0
# 4             89            4        500.0
# ...          ...          ...          ...
# 1387423  1444051            1        225.0
# 1387424  1444053            1        725.0
# 1387425  1444058            1         25.0
# 1387426  1444063            1         50.0
# 1387427  1444065            1         25.0
#
# [1387428 rows x 3 columns]

# %%
money_lent['money_per_lender']=money_lent['loan_amount']/money_lent['num_lenders']
money_lent
# Out:
#          loan_id  num_lenders  loan_amount  money_per_lender
# 0             84            3        500.0        166.666667
# 1             85            2        500.0        250.000000
# 2             86            3        500.0        166.666667
# 3             88            3        300.0        100.000000
# 4             89            4        500.0        125.000000
# ...          ...          ...          ...               ...
# 1387423  1444051            1        225.0        225.000000
# 1387424  1444053            1        725.0        725.000000
# 1387425  1444058            1         25.0         25.000000
# 1387426  1444063            1         50.0         50.000000
# 1387427  1444065            1         25.0         25.000000
#
# [1387428 rows x 4 columns]

# %%
norm_money = norm.merge(money_lent[['loan_id', 'money_per_lender']], on='loan_id')
norm_money
# Out:
#           loan_id             lenders  money_per_lender
# 0          483693              muc888            30.625
# 1          483693             sam4326            30.625
# 2          483693         camaran3922            30.625
# 3          483693         lachheb1865            30.625
# 4          483693         rebecca3499            30.625
# ...           ...                 ...               ...
# 28293907  1206425   trogdorfamily7622            40.625
# 28293908  1206425           danny6470            40.625
# 28293909  1206425             don6118            40.625
# 28293910  1206486            alan5175            75.000
# 28293911  1206486         amy38101311            75.000
#
# [28293912 rows x 3 columns]

# %%
norm_money=norm_money.groupby('lenders').sum()['money_per_lender']
norm_money
# Out:
# lenders
#  000               1672.618411
#  00000             1380.693644
#  0002              2472.563566
#  00mike00            52.631579
#  0101craign0101    2623.565117
#                       ...
# zzanita              87.500000
# zzcyna7269           55.357143
# zzinnia              38.000000
# zzmcfate           2287.291955
# zzrvmf8538          106.417625
# Name: money_per_lender, Length: 1639026, dtype: float64

# %% [markdown]
# #### 9.For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.

# %%
money_funded=loans.groupby('country_name')['funded_amount'].sum()
money_funded=money_funded.to_frame()
money_funded
# Out:
#                 funded_amount
# country_name
# Afghanistan         1964650.0
# Albania             3992475.0
# Armenia            20284675.0
# Azerbaijan         14191350.0
# Belize               150175.0
# ...                       ...
# Vietnam            23463825.0
# Virgin Islands            0.0
# Yemen               3340025.0
# Zambia              1913250.0
# Zimbabwe            5818550.0
#
# [96 rows x 1 columns]

# %%
differences= money_country.merge(money_funded, how= 'outer', on= 'country_name')
differences['diff']= differences['loan_amount']- differences['funded_amount']

# %%
differences
# Out:
#                 loan_amount  funded_amount       diff
# country_name
# Afghanistan       1967950.0      1964650.0     3300.0
# Albania           4307350.0      3992475.0   314875.0
# Armenia          22950475.0     20284675.0  2665800.0
# Azerbaijan       14784625.0     14191350.0   593275.0
# Belize             150175.0       150175.0        0.0
# ...                     ...            ...        ...
# Vietnam          24681100.0     23463825.0  1217275.0
# Virgin Islands      10000.0            0.0    10000.0
# Yemen             3444000.0      3340025.0   103975.0
# Zambia            1978975.0      1913250.0    65725.0
# Zimbabwe          5851875.0      5818550.0    33325.0
#
# [96 rows x 3 columns]

# %% [markdown]
# #### 10.Which country has the highest ratio between the difference computed at the previous point and the population?

# %%
country= pd.read_csv('country_stats.csv')

# %%
country
# Out:
#                  country_name country_code country_code3 continent  \
# 0                       India           IN           IND      Asia
# 1                     Nigeria           NG           NGA    Africa
# 2                      Mexico           MX           MEX  Americas
# 3                    Pakistan           PK           PAK      Asia
# 4                  Bangladesh           BD           BGD      Asia
# ..                        ...          ...           ...       ...
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#               region  population  population_below_poverty_line       hdi  \
# 0      Southern Asia  1339180127                           21.9  0.623559
# 1     Western Africa   190886311                           70.0  0.527105
# 2    Central America   129163276                           46.2  0.761683
# 3      Southern Asia   197015955                           29.5  0.550354
# 4      Southern Asia   164669751                           31.5  0.578824
# ..               ...         ...                            ...       ...
# 169   Eastern Africa    14742523                            NaN       NaN
# 170    Middle Africa     4659080                            NaN  0.352440
# 171        Polynesia      196440                            NaN  0.702000
# 172     Western Asia     4920724                            NaN  0.677000
# 173  Southern Europe     1895250                           30.0  0.786000
#
#      life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0             68.322                    11.696590                 6.298834
# 1             53.057                     9.970482                 6.000000
# 2             76.972                    13.299090                 8.554985
# 3             66.365                     8.106910                 5.089460
# 4             71.985                    10.178706                 5.241577
# ..               ...                          ...                      ...
# 169              NaN                          NaN                      NaN
# 170           51.458                     7.098980                 4.230000
# 171              NaN                          NaN                      NaN
# 172              NaN                          NaN                      NaN
# 173              NaN                          NaN                      NaN
#
#               gni         kiva_country_name
# 0     5663.474799                     India
# 1     5442.901264                   Nigeria
# 2    16383.106680                    Mexico
# 3     5031.173074                  Pakistan
# 4     3341.490722                Bangladesh
# ..            ...                       ...
# 169           NaN                   Somalia
# 170    587.473961  Central African Republic
# 171           NaN                     Samoa
# 172           NaN                 Palestine
# 173           NaN                    Kosovo
#
# [174 rows x 13 columns]

# %%
country_money= differences.merge(country[['country_name', 'population', 'population_below_poverty_line']], on= 'country_name')
country_money
# Out:
#      country_name  loan_amount  funded_amount       diff  population  \
# 0     Afghanistan    1967950.0      1964650.0     3300.0    35530081
# 1         Albania    4307350.0      3992475.0   314875.0     2930187
# 2         Armenia   22950475.0     20284675.0  2665800.0     2930450
# 3      Azerbaijan   14784625.0     14191350.0   593275.0     9827589
# 4          Belize     150175.0       150175.0        0.0      374681
# ..            ...          ...            ...        ...         ...
# 81  United States   46352000.0     36365340.0  9986660.0   324459463
# 82        Uruguay       8000.0         8000.0        0.0     3456750
# 83          Yemen    3444000.0      3340025.0   103975.0    28250420
# 84         Zambia    1978975.0      1913250.0    65725.0    17094130
# 85       Zimbabwe    5851875.0      5818550.0    33325.0    16529904
#
#     population_below_poverty_line
# 0                            35.8
# 1                            14.3
# 2                            32.0
# 3                             4.9
# 4                            41.0
# ..                            ...
# 81                           15.1
# 82                            9.7
# 83                           54.0
# 84                           60.5
# 85                           72.3
#
# [86 rows x 6 columns]

# %%
country_money['ratio']= country_money['diff']/country_money['population']
country_money
# Out:
#      country_name  loan_amount  funded_amount       diff  population  \
# 0     Afghanistan    1967950.0      1964650.0     3300.0    35530081
# 1         Albania    4307350.0      3992475.0   314875.0     2930187
# 2         Armenia   22950475.0     20284675.0  2665800.0     2930450
# 3      Azerbaijan   14784625.0     14191350.0   593275.0     9827589
# 4          Belize     150175.0       150175.0        0.0      374681
# ..            ...          ...            ...        ...         ...
# 81  United States   46352000.0     36365340.0  9986660.0   324459463
# 82        Uruguay       8000.0         8000.0        0.0     3456750
# 83          Yemen    3444000.0      3340025.0   103975.0    28250420
# 84         Zambia    1978975.0      1913250.0    65725.0    17094130
# 85       Zimbabwe    5851875.0      5818550.0    33325.0    16529904
#
#     population_below_poverty_line     ratio
# 0                            35.8  0.000093
# 1                            14.3  0.107459
# 2                            32.0  0.909690
# 3                             4.9  0.060368
# 4                            41.0  0.000000
# ..                            ...       ...
# 81                           15.1  0.030779
# 82                            9.7  0.000000
# 83                           54.0  0.003680
# 84                           60.5  0.003845
# 85                           72.3  0.002016
#
# [86 rows x 7 columns]

# %%
country_money.sort_values("ratio", axis = 0, ascending = False)
# Out:
#         country_name  loan_amount  funded_amount       diff  population  \
# 64             Samoa   12212175.0     11508250.0   703925.0      196440
# 2            Armenia   22950475.0     20284675.0  2665800.0     2930450
# 26       El Salvador   41691550.0     37881675.0  3809875.0     6377853
# 73        Tajikistan   39622125.0     37049825.0  2572300.0     8921343
# 56         Palestine   22316675.0     20911075.0  1405600.0     4920724
# ..               ...          ...            ...        ...         ...
# 41           Lesotho     516450.0       516450.0        0.0     2233339
# 46        Mauritania      15000.0        15000.0        0.0     4420184
# 51           Namibia      39525.0        39525.0        0.0     2533794
# 71         Sri Lanka      74800.0        74800.0        0.0    20876917
# 58  Papua New Guinea      50000.0        50000.0        0.0     8251162
#
#     population_below_poverty_line     ratio
# 64                            NaN  3.583410
# 2                            32.0  0.909690
# 26                           34.9  0.597360
# 73                           31.5  0.288331
# 56                            NaN  0.285649
# ..                            ...       ...
# 41                           57.0  0.000000
# 46                           31.0  0.000000
# 51                           28.7  0.000000
# 71                            6.7  0.000000
# 58                           37.0  0.000000
#
# [86 rows x 7 columns]

# %% [markdown]
# #### 11.Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?

# %%
country_money['poor_pop']= country_money['population']* country_money['population_below_poverty_line']/100

# %%
country_money['ratio2']= country_money['diff']/country_money['poor_pop']
country_money.sort_values("ratio2", axis = 0, ascending = False)
# Out:
#        country_name  loan_amount  funded_amount       diff  population  \
# 2           Armenia   22950475.0     20284675.0  2665800.0     2930450
# 26      El Salvador   41691550.0     37881675.0  3809875.0     6377853
# 27          Georgia    9570425.0      8994450.0   575975.0     3912061
# 3        Azerbaijan   14784625.0     14191350.0   593275.0     9827589
# 73       Tajikistan   39622125.0     37049825.0  2572300.0     8921343
# ..              ...          ...            ...        ...         ...
# 56        Palestine   22316675.0     20911075.0  1405600.0     4920724
# 62      Puerto Rico     441900.0       362600.0    79300.0     3663131
# 64            Samoa   12212175.0     11508250.0   703925.0      196440
# 67  Solomon Islands     815575.0       806275.0     9300.0      611343
# 68          Somalia     308725.0       308725.0        0.0    14742523
#
#     population_below_poverty_line     ratio     poor_pop    ratio2
# 2                            32.0  0.909690   937744.000  2.842780
# 26                           34.9  0.597360  2225870.697  1.711634
# 27                            9.2  0.147231   359909.612  1.600332
# 3                             4.9  0.060368   481551.861  1.232006
# 73                           31.5  0.288331  2810223.045  0.915337
# ..                            ...       ...          ...       ...
# 56                            NaN  0.285649          NaN       NaN
# 62                            NaN  0.021648          NaN       NaN
# 64                            NaN  3.583410          NaN       NaN
# 67                            NaN  0.015212          NaN       NaN
# 68                            NaN  0.000000          NaN       NaN
#
# [86 rows x 9 columns]

# %% [markdown]
# #### 12.For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD 31 / (31+365+30) = 363.85 for 2016, 5000USD 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.

# %%
loans=loans.dropna(subset=['planned_expiration_time'])
loans=loans.dropna(subset=['disburse_time'])
loans=loans.reset_index(drop=True )
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1044957   988180                 NaN               NaN
# 1044958   988213             Perlita           English
# 1044959   989109  Okyeso Nyame Group           English
# 1044960   989143            Exequila           English
# 1044961   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1044957                                                NaN
# 1044958  Perlita is 52 years old, married and has three...
# 1044959  Okyeso Nyame group will begin its third cycle ...
# 1044960  Exequila  is from San Miguel, Bohol. She is in...
# 1044961  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1044957                                                NaN          400.0
# 1044958  Perlita is 52 years old, married and has three...          300.0
# 1044959  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1044960  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1044961  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  ... lender_term  \
# 0              125.0  funded  General Store       Retail  ...         7.0
# 1              400.0  funded  Used Clothing     Clothing  ...         8.0
# 2              400.0  funded  General Store       Retail  ...        14.0
# 3              625.0  funded        Farming  Agriculture  ...        14.0
# 4              425.0  funded        Farming  Agriculture  ...         7.0
# ...              ...     ...            ...          ...  ...         ...
# 1044957        400.0  funded      Tailoring     Services  ...        14.0
# 1044958        300.0  funded           Pigs  Agriculture  ...        14.0
# 1044959       2425.0  funded         Bakery         Food  ...         8.0
# 1044960        100.0  funded        Farming  Agriculture  ...        12.0
# 1044961        175.0  funded         Sewing     Services  ...        14.0
#
#         num_lenders_total num_journal_entries num_bulk_entries  \
# 0                       3                   2                1
# 1                      11                   2                1
# 2                      16                   2                1
# 3                      21                   2                1
# 4                      15                   2                1
# ...                   ...                 ...              ...
# 1044957                16                   4                2
# 1044958                12                   1                1
# 1044959                76                   2                1
# 1044960                 3                   1                1
# 1044961                 7                   1                1
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1044957        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1044958  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1044959  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1044960                                                NaN
# 1044961                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1044957                                         NaN
# 1044958                                      female
# 1044959  female, female, female, male, male, female
# 1044960                                      female
# 1044961                                      female
#
#                           borrower_pictured  repayment_interval  \
# 0                                      true           irregular
# 1                                      true             monthly
# 2                                      true             monthly
# 3                                      true             monthly
# 4                                      true              bullet
# ...                                     ...                 ...
# 1044957                                 NaN             monthly
# 1044958                                true           irregular
# 1044959  true, true, true, true, true, true           irregular
# 1044960                                true           irregular
# 1044961                                true             monthly
#
#         distribution_model         duration
# 0            field_partner 53 days 19:30:06
# 1            field_partner 96 days 14:25:07
# 2            field_partner 37 days 13:10:05
# 3            field_partner 34 days 19:10:02
# 4            field_partner 57 days 22:10:02
# ...                    ...              ...
# 1044957      field_partner 39 days 17:00:03
# 1044958      field_partner 39 days 08:40:07
# 1044959      field_partner 51 days 14:20:04
# 1044960      field_partner 63 days 00:50:02
# 1044961      field_partner 61 days 12:50:06
#
# [1044962 rows x 32 columns]

# %%
#prestito piu vecchio
loans.iloc[loans['disburse_time'].idxmin()]
# Out:
# loan_id                                                                       358219
# loan_name                                                                 Mirismayil
# original_language                                                            English
# description                        Mirismayil is a 28-year-old trader who sells d...
# description_translated                                                           NaN
# funded_amount                                                                   2300
# loan_amount                                                                     2300
# status                                                                        funded
# activity_name                                                         Clothing Sales
# sector_name                                                                 Clothing
# loan_use                                                    to purchase more clothes
# country_code                                                                      AZ
# country_name                                                              Azerbaijan
# town_name                                                                       Agsu
# currency_policy                                                           not shared
# currency_exchange_coverage_rate                                                  NaN
# currency                                                                         AZN
# partner_id                                                                        56
# posted_time                                            2011-11-15 12:41:54.000 +0000
# planned_expiration_time                                    2012-02-11 22:50:58+00:00
# disburse_time                                              2011-10-18 07:00:00+00:00
# raised_time                                            2012-02-01 05:15:58.000 +0000
# lender_term                                                                       17
# num_lenders_total                                                                 78
# num_journal_entries                                                                1
# num_bulk_entries                                                                   1
# tags                                                                             NaN
# borrower_genders                                                                male
# borrower_pictured                                                               true
# repayment_interval                                                           monthly
# distribution_model                                                     field_partner
# duration                                                           116 days 15:50:58
# Name: 851626, dtype: object

# %%
#prestito piu recente
loans.iloc[loans['planned_expiration_time'].idxmax()]
# Out:
# loan_id                                                                      1444085
# loan_name                                                                        NaN
# original_language                                                            English
# description                        To pay for feed and a hutch for the turduckens...
# description_translated             To pay for feed and a hutch for the turduckens...
# funded_amount                                                                      0
# loan_amount                                                                       25
# status                                                                   fundRaising
# activity_name                                                              Livestock
# sector_name                                                              Agriculture
# loan_use                           to start a turducken farm. - this loan use has...
# country_code                                                                      KE
# country_name                                                                   Kenya
# town_name                                                                        NaN
# currency_policy                                                               shared
# currency_exchange_coverage_rate                                                  0.1
# currency                                                                         KES
# partner_id                                                                       138
# posted_time                                            2018-01-11 07:11:23.000 +0000
# planned_expiration_time                                    2018-02-10 07:35:04+00:00
# disburse_time                                              2018-01-10 08:00:00+00:00
# raised_time                                                                      NaN
# lender_term                                                                       13
# num_lenders_total                                                                  0
# num_journal_entries                                                                1
# num_bulk_entries                                                                   1
# tags                                                                             NaN
# borrower_genders                                                              female
# borrower_pictured                                                               true
# repayment_interval                                                           monthly
# distribution_model                                                     field_partner
# duration                                                            30 days 23:35:04
# Name: 180901, dtype: object

# %%
#ammontare giornaliero
loans['daily']= loans['loan_amount']/loans['duration'].dt.days
loans['daily']
# Out:
# 0           2.358491
# 1           4.166667
# 2          10.810811
# 3          18.382353
# 4           7.456140
#              ...
# 1044957    10.256410
# 1044958     7.692308
# 1044959    47.549020
# 1044960     1.587302
# 1044961     2.868852
# Name: daily, Length: 1044962, dtype: float64

# %%
diz={}
for current_year in range(2011, 2019): #per ogni anno nel range dei prestiti
    temp=loans[(loans['disburse_time'].dt.year<=current_year) & (loans['planned_expiration_time'].dt.year>=current_year)]
    diz[current_year]=0 #selezioni i prestiti in corso in quell anno
    for row in temp.index:
        if temp.at[row, 'disburse_time'].year < current_year: #iniziato prima
            if temp.at[row, 'planned_expiration_time'].year == current_year: #finisce nell anno
                diz[current_year]+= temp.at[row, 'planned_expiration_time'].dayofyear* temp.at[row, 'daily']
            if temp.at[row, 'planned_expiration_time'].year > current_year: #non finisce in quell anno
                if (current_year == 2012 | current_year == 2016):
                    diz[current_year]+= 366* temp.at[row, 'daily']
                else:
                    diz[current_year]+= 365* temp.at[row, 'daily']
        if temp.at[row, 'disburse_time'].year == current_year: #iniziato in quell anno
            if temp.at[row, 'planned_expiration_time'].year == current_year: #finisce nell anno
                diz[current_year]+= temp.at[row, 'loan_amount']
            if temp.at[row, 'planned_expiration_time'].year > current_year: #non finisce in quell anno
                if (current_year == 2012 | current_year == 2016):
                    diz[current_year]+= (366-temp.at[row, 'disburse_time'].dayofyear) * temp.at[row, 'daily']
                else:
                    diz[current_year]+= (365-temp.at[row, 'disburse_time'].dayofyear) * temp.at[row, 'daily']

# %%
diz
# Out:
# {2011: 631678.3440311765,
#  2012: 113022011.54589057,
#  2013: 125036380.29227056,
#  2014: 153278613.4132631,
#  2015: 159882303.38875186,
#  2016: 158649804.14773685,
#  2017: 171979395.62687504,
#  2018: 5735473.345945817}
